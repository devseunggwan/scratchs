# %%
import os
import time

import duckdb
import httpx
import pandas as pd
import matplotlib.pyplot as plt
from retry import retry
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
import json


def write_json(data, filename='data.json'):
    with open(filename, 'w') as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

# %%
@retry(Exception, tries=3, delay=1, backoff=2, jitter=3)
def get_transaction(network, collection_id, continuation="", type=["sale", "transfer", "mint"], last_timestamp: int = -1):
    networks = {"ethereum": "api", "polygon": "api-polygon"}

    url = f"https://{networks[network]}.reservoir.tools/collections/activity/v6"

    headers = {
        "accept": "*/*",
        "content-type": "application/json",
        "x-api-key": os.getenv("RESERVOIR_API_KEY"),
    }
    params = {
        "collection": collection_id,
        "limit": 50,
        "types": type,
    }

    if continuation != "":
        params["continuation"] = continuation

    resp = httpx.get(url, params=params, headers=headers, timeout=30)

    # 200번 이외 경우에 에러를 반환하여 재시도를 하도록 함.
    resp.raise_for_status()

    resp = resp.json()
    
    if last_timestamp != -1:
        resp["activities"] = [activity for activity in resp["activities"] if activity["timestamp"] > last_timestamp]
    
    if len(resp["activities"]) == 0:
        resp["continuation"] = None
    
    for activity in resp["activities"]:
        activity["network"] = network
        activity["collection_id"] = collection_id
        
    return resp

# %%
resp = get_transaction("ethereum", "0x06012c8cf97bead5deae237070f9587f8e7a266d", type=["mint"])
write_json(resp, "output/mint3.json")

# %%
resp = get_transaction("ethereum", "0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d", type=["mint"], last_timestamp=1668322751)
resp

# %%
df = duckdb.read_json("output/mint/*.json").to_df()
df = pd.concat([pd.json_normalize(row["activities"]) for idx, row in df.iterrows()]).reset_index(drop=True)
df
# Out:
# /var/folders/k3/2w4zylcs0l12r34ky2dtqg5h0000gn/T/ipykernel_89708/2450108895.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([pd.json_normalize(row["activities"]) for idx, row in df.iterrows()]).reset_index(drop=True)
#     type                                 fromAddress  \
# 0   mint  0x0000000000000000000000000000000000000000
# 1   mint  0x0000000000000000000000000000000000000000
# 2   mint  0x0000000000000000000000000000000000000000
# 3   mint  0x0000000000000000000000000000000000000000
# 4   mint  0x0000000000000000000000000000000000000000
# 5   mint  0x0000000000000000000000000000000000000000
# 6   mint  0x0000000000000000000000000000000000000000
# 7   mint  0x0000000000000000000000000000000000000000
# 8   mint  0x0000000000000000000000000000000000000000
# 9   mint  0x0000000000000000000000000000000000000000
# 10  mint  0x0000000000000000000000000000000000000000
# 11  mint  0x0000000000000000000000000000000000000000
# 12  mint  0x0000000000000000000000000000000000000000
# 13  mint  0x0000000000000000000000000000000000000000
# 14  mint  0x0000000000000000000000000000000000000000
# 15  mint  0x0000000000000000000000000000000000000000
# 16  mint  0x0000000000000000000000000000000000000000
# 17  mint  0x0000000000000000000000000000000000000000
# 18  mint  0x0000000000000000000000000000000000000000
# 19  mint  0x0000000000000000000000000000000000000000
# 20  mint  0x0000000000000000000000000000000000000000
# 21  mint  0x0000000000000000000000000000000000000000
# 22  mint  0x0000000000000000000000000000000000000000
# 23  mint  0x0000000000000000000000000000000000000000
# 24  mint  0x0000000000000000000000000000000000000000
# 25  mint  0x0000000000000000000000000000000000000000
# 26  mint  0x0000000000000000000000000000000000000000
# 27  mint  0x0000000000000000000000000000000000000000
# 11  0xc5d05f5dcac54d265cd7519b80939c49f5381ec31a70...       141           1
# 12  0x7edca72d510fa32c2b8954a29ee0ade9203f1872d157...       143           1
# 13  0x01a4c4e653a05edff55070a6a9feb1affb42396c3093...       262           1
# 14  0x685ed5747aa115da2e9f9b229c9646eb55de6282ef4b...       444           1
# 15  0xf0adf1c87a282d23fd342911423bc0be9f2df71f0a59...       291           1
# 16  0xb009fb40fec12cb2d8259ad67e45b5cb15ec6d3145c4...       146           1
# 17  0xd8c8c73d81e916a0ad15a18354c8de7ac00d0a7ffd37...       163           1
# 18  0xa5bc6c27f5ed7d279e4285ff6a188d29014c46c0fea1...        74           1
# 19  0xe719b90b4fd45ae9ea3433d30d8fbb9f4a82a87ac53b...       162           1
# 20  0xac6b5fa12fc2de259458880e9f903484cfecb305a7c2...        78           1
# 21  0x669817477711c232ee1acc8f4f08aedac7bbca8f75ba...       266           1
# 22  0x0f73733396c51a97d8cb2036da97ba223b1506a6a511...       381           1
# 23  0x067b998b304c7728889298b24116dd06ce080037941e...       444           1
# 24  0xe6a049d05c7834db43abcc66bbdef6dca3a28ccff955...       384           1
# 25  0x6a7806e8b588669742417f70d8ea77f99d66f5a9a5d3...       351           1
# 26  0xf7365efba17e7c239812f3bd6df9d364fe30c19d0eb1...       294           1
# 27  0x404a4ff8a57837f7c2002acded3e4f9ffb87b744f02a...       492           1
# 28  0x8e91c5b07502269fd60512b0c772ef31455a3d047065...       273           1
# 29  0x271707bedb7d3966b4c84191c78b4c07a5498ad168ea...       460           1
# 30  0xa7e17dc4f57fc310aafb924a2a9a70677923d3469193...       297           1
# 31  0x04a048dacd347f23829ae90f6f91653c67a188d82d53...       257           1
#
#     ...  token.isNsfw  token.tokenName  \
# 0   ...         False  Lil Pudgy #7451
# 1   ...         False      DeGod #9939
# 2   ...         False      DeGod #1379
# 3   ...         False      DeGod #7096
# 4   ...         False      DeGod #1248
# 5   ...         False      DeGod #4877
# 6   ...         False      DeGod #8216
# 7   ...         False      DeGod #1427
# 8   ...         False      DeGod #1553
# 9   ...         False      DeGod #5378
# 10  ...         False      DeGod #4046
# 11  ...         False      DeGod #5584
# 12  ...         False      DeGod #1246
# 13  ...         False      DeGod #2838
# 14  ...         False      DeGod #7096
# 15  ...         False     Kanpai Panda
# 16  ...         False     Kanpai Panda
# 17  ...         False     Kanpai Panda
# 18  ...         False     Kanpai Panda
# 19  ...         False     Kanpai Panda
# 20  ...         False     Kanpai Panda
# 21  ...         False     Kanpai Panda
# 22  ...         False           W#9367
# 23  ...         False             None
# 24  ...         False           W#3290
# 25  ...         False           W#9428
# 26  ...         False           W#8895
# 27  ...         False           W#4319
# 28  ...         False           W#6340
# 29  ...         False           W#9338
# 30  ...         False           W#5084
# 31  ...         False           W#8381
#
#                                      token.tokenImage token.rarityScore  \
# 0   https://img.reservoir.tools/images/v2/mainnet/...           159.085
# 1   https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 2   https://img.reservoir.tools/images/v2/mainnet/...           144.818
# 3   https://img.reservoir.tools/images/v2/mainnet/...           216.209
# 4   https://img.reservoir.tools/images/v2/mainnet/...           113.456
# 5   https://img.reservoir.tools/images/v2/mainnet/...            71.633
# 6   https://img.reservoir.tools/images/v2/mainnet/...           133.774
# 7   https://img.reservoir.tools/images/v2/mainnet/...           102.663
# 8   https://img.reservoir.tools/images/v2/mainnet/...           116.810
# 9   https://img.reservoir.tools/images/v2/mainnet/...           120.385
# 10  https://img.reservoir.tools/images/v2/mainnet/...           197.702
# 11  https://img.reservoir.tools/images/v2/mainnet/...           279.552
# 12  https://img.reservoir.tools/images/v2/mainnet/...           160.457
# 13  https://img.reservoir.tools/images/v2/mainnet/...           134.859
# 14  https://img.reservoir.tools/images/v2/mainnet/...           216.209
# 15  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 16  https://img.reservoir.tools/images/v2/mainnet/...          2290.879
# 17  https://img.reservoir.tools/images/v2/mainnet/...          2302.324
# 18  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 19  https://img.reservoir.tools/images/v2/mainnet/...          2525.770
# 20  https://img.reservoir.tools/images/v2/mainnet/...          2365.556
# 21  https://img.reservoir.tools/images/v2/mainnet/...          2321.834
# 22  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 23                                               None               NaN
# 24  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 25  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 26  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 27  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 28  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 29  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 30  https://img.reservoir.tools/images/v2/mainnet/...               NaN
# 31  https://img.reservoir.tools/images/v2/mainnet/...               NaN
#
#    token.rarityRank                     collection.collectionId  \
# 0           15994.0  0x524cab2ec69124574082676e6f654a18df49a048
# 1               NaN  0x8821bee2ba0df28761afff119d66390d594cd280
# 2            1584.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 3             210.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 4            3094.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 5            5498.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 6            1793.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 7            3918.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 8            2876.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 9            2619.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 10            322.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 11             39.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 12            823.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 13           1734.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 14            210.0  0x8821bee2ba0df28761afff119d66390d594cd280
# 15              NaN  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 16           7164.0  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 17           6959.0  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 18              NaN  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 19           3240.0  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 20           5776.0  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 21           6588.0  0xacf63e56fd08970b43401492a02f6f38b6635c91
# 22              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 23              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 24              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 25              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 26              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 27              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 28              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 29              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 30              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
# 31              NaN  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6
#
#     collection.isSpam collection.isNsfw  collection.collectionName  \
# 0               False             False                 Lil Pudgys
# 1               False             False                     DeGods
# 2               False             False                     DeGods
# 3               False             False                     DeGods
# 4               False             False                     DeGods
# 5               False             False                     DeGods
# 6               False             False                     DeGods
# 7               False             False                     DeGods
# 8               False             False                     DeGods
# 9               False             False                     DeGods
# 10              False             False                     DeGods
# 11              False             False                     DeGods
# 12              False             False                     DeGods
# 13              False             False                     DeGods
# 14              False             False                     DeGods
# 15              False             False              Kanpai Pandas
# 16              False             False              Kanpai Pandas
# 17              False             False              Kanpai Pandas
# 18              False             False              Kanpai Pandas
# 19              False             False              Kanpai Pandas
# 20              False             False              Kanpai Pandas
# 21              False             False              Kanpai Pandas
# 22              False             False        Wrapped Cryptopunks
# 23              False             False        Wrapped Cryptopunks
# 24              False             False        Wrapped Cryptopunks
# 25              False             False        Wrapped Cryptopunks
# 26              False             False        Wrapped Cryptopunks
# 27              False             False        Wrapped Cryptopunks
# 28              False             False        Wrapped Cryptopunks
# 29              False             False        Wrapped Cryptopunks
# 30              False             False        Wrapped Cryptopunks
# 31              False             False        Wrapped Cryptopunks
#
#                            collection.collectionImage
# 0   https://img.reservoir.tools/images/v2/mainnet/...
# 1   https://img.reservoir.tools/images/v2/mainnet/...
# 2   https://img.reservoir.tools/images/v2/mainnet/...
# 3   https://img.reservoir.tools/images/v2/mainnet/...
# 4   https://img.reservoir.tools/images/v2/mainnet/...
# 5   https://img.reservoir.tools/images/v2/mainnet/...
# 6   https://img.reservoir.tools/images/v2/mainnet/...
# 7   https://img.reservoir.tools/images/v2/mainnet/...
# 8   https://img.reservoir.tools/images/v2/mainnet/...
# 9   https://img.reservoir.tools/images/v2/mainnet/...
# 10  https://img.reservoir.tools/images/v2/mainnet/...
# 11  https://img.reservoir.tools/images/v2/mainnet/...
# 12  https://img.reservoir.tools/images/v2/mainnet/...
# 13  https://img.reservoir.tools/images/v2/mainnet/...
# 14  https://img.reservoir.tools/images/v2/mainnet/...
# 15  https://img.reservoir.tools/images/v2/mainnet/...
# 16  https://img.reservoir.tools/images/v2/mainnet/...
# 17  https://img.reservoir.tools/images/v2/mainnet/...
# 18  https://img.reservoir.tools/images/v2/mainnet/...
# 19  https://img.reservoir.tools/images/v2/mainnet/...
# 20  https://img.reservoir.tools/images/v2/mainnet/...
# 21  https://img.reservoir.tools/images/v2/mainnet/...
# 22  https://img.reservoir.tools/images/v2/mainnet/...
# 23  https://img.reservoir.tools/images/v2/mainnet/...
# 24  https://img.reservoir.tools/images/v2/mainnet/...
# 25  https://img.reservoir.tools/images/v2/mainnet/...
# 26  https://img.reservoir.tools/images/v2/mainnet/...
# 27  https://img.reservoir.tools/images/v2/mainnet/...
# 28  https://img.reservoir.tools/images/v2/mainnet/...
# 29  https://img.reservoir.tools/images/v2/mainnet/...
# 30  https://img.reservoir.tools/images/v2/mainnet/...
# 31  https://img.reservoir.tools/images/v2/mainnet/...
#
# [32 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['type', 'fromAddress', 'toAddress', 'amount', 'timestamp', 'createdAt',
#        'contract', 'txHash', 'logIndex', 'batchIndex', 'isAirdrop', 'network',
#        'collection_id', 'price.currency.contract', 'price.currency.name',
#        'price.currency.symbol', 'price.currency.decimals', 'price.amount.raw',
#        'price.amount.decimal', 'price.amount.usd', 'price.amount.native',
#        'token.tokenId', 'token.isSpam', 'token.isNsfw', 'token.tokenName',
#        'token.tokenImage', 'token.rarityScore', 'token.rarityRank',
#        'collection.collectionId', 'collection.isSpam', 'collection.isNsfw',
#        'collection.collectionName', 'collection.collectionImage'],
#       dtype='object')

# %%
df.loc[df['timestamp'] > 1717745231]

df[["network", "collection_id", "token.tokenId", "token.tokenName",  "timestamp"]]
# Out:
#      network                               collection_id   timestamp
# 0   ethereum  0x524cab2ec69124574082676e6f654a18df49a048  1718764883
# 1   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718847635
# 2   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718838779
# 3   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718836571
# 4   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718834303
# 5   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718834291
# 6   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718828147
# 7   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718824967
# 8   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718799563
# 9   ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718786399
# 10  ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718786303
# 11  ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718786291
# 12  ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718786291
# 13  ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718786279
# 14  ethereum  0x8821bee2ba0df28761afff119d66390d594cd280  1718774519
# 15  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718871911
# 16  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718843375
# 17  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718843351
# 18  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718843303
# 19  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718843267
# 20  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718803487
# 21  ethereum  0xacf63e56fd08970b43401492a02f6f38b6635c91  1718803127
# 22  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718872115
# 23  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718872079
# 24  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718871947
# 25  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718871743
# 26  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718871635
# 27  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718871587
# 28  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718871539
# 29  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718866139
# 30  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718854907
# 31  ethereum  0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  1718847623

# %% [markdown]
# ### Transaction Sync

# %%
@retry(Exception, tries=3, delay=1, backoff=2, jitter=3)
def get_transfer_bulk(network, collection_id, continuation="", start_timestamp=-1, end_timestamp=-1):
    networks = {"ethereum": "api", "polygon": "api-polygon"}

    url = f"https://{networks[network]}.reservoir.tools/transfers/bulk/v2"

    headers = {
        "accept": "*/*",
        "content-type": "application/json",
        "x-api-key": os.getenv("RESERVOIR_API_KEY"),
    }
    params = {
        "contract": collection_id,
        "limit": 1000,
    }

    if continuation != "":
        params["continuation"] = continuation
        
    if start_timestamp != -1:
        params["startTimestamp"] = start_timestamp
    
    if end_timestamp != -1:
        params["endTimestamp"] = end_timestamp

    resp = httpx.get(url, params=params, headers=headers, timeout=30)

    # 200번 이외 경우에 에러를 반환하여 재시도를 하도록 함.
    resp.raise_for_status()

    resp = resp.json()
    for transfer in resp["transfers"]:
        transfer["network"] = network
        transfer["collection_id"] = collection_id
    

    return resp

# %%
resp = get_transfer_bulk("ethereum", "0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d", start_timestamp=1718693423)
write_json(resp, "output/transfer_bulk.json")

# %%
start_timestamp = 1718693423
end_timestamp = int(time.time())
continuation = ""

while True:
    resp = get_transfer_bulk("ethereum", "0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d", start_timestamp=start_timestamp, end_timestamp=end_timestamp, continuation=continuation)
    write_json(resp, f"output/transfer_bulk_{start_timestamp}_{continuation}.json")
    
    continuation = resp["continuation"]
    
    if continuation in [None, ""]:
        break

# %%
df = duckdb.read_json("output/*.json")

# %%
transfers = df["transfers"].fetchdf()
transfers

# %%
flatten = pd.concat([pd.json_normalize(row["transfers"]) for idx, row in transfers.iterrows()])

# %%
flatten

# %%
flatten.shape

# %%
# Assuming the timestamps are stored in the 'timestamp' column of the 'flatten' DataFrame
timestamps = flatten['timestamp']

# Plotting the histogram of timestamps
plt.hist(timestamps)
plt.xlabel('Timestamp')
plt.ylabel('Frequency')
plt.title('Distribution of Timestamps')
plt.show()

# %%
flatten.duplicated().sum()

# %%
1718693423

# %%
time.time()

# %%
time.time() - 1718693423

# %%
(time.time() - 1718693423) / 60 / 60 / 24

# %%
flatten.loc[flatten["timestamp"] < 1718769000]

# %%
flatten.iloc[0].txHash

# %%
flatten["token.tokenId"].value_counts()

# %% [markdown]
# ### Sale Sync

# %%
@retry(Exception, tries=3, delay=1, backoff=2, jitter=3)
def get_sale(network, collection_id, continuation="", start_timestamp=-1, end_timestamp=-1):
    networks = {"ethereum": "api", "polygon": "api-polygon"}

    url = f"https://{networks[network]}.reservoir.tools/sales/v6"

    headers = {
        "accept": "*/*",
        "content-type": "application/json",
        "x-api-key": os.getenv("RESERVOIR_API_KEY"),
    }
    params = {
        "collection": collection_id,
        "limit": 1000
    }

    if continuation != "":
        params["continuation"] = continuation

    if start_timestamp != -1:
        params["startTimestamp"] = start_timestamp
    
    if end_timestamp != -1:
        params["endTimestamp"] = end_timestamp
    
    resp = httpx.get(url, params=params, headers=headers, timeout=30)

    # 200번 이외 경우에 에러를 반환하여 재시도를 하도록 함.
    resp.raise_for_status()

    resp = resp.json()

    for sale in resp["sales"]:
        sale["network"] = network
        sale["collection_id"] = collection_id
    
    return resp

# %%
network = "ethereum"
collection_id = "0xed5af388653567af2f388e6224dc7c4b3241c544"
continuation = ""
start_timestamp = 1718693423
end_timestamp = int(time.time())

timestamp = int(time.time())

# 14분 30초 이후
while int(time.time()) - timestamp < 870:
    sales = get_sale(network, collection_id, continuation, start_timestamp=start_timestamp, end_timestamp=end_timestamp)
    write_json(sales, f"output/sale/sale_{continuation}.json")
    
    continuation = sales["continuation"]
    
    if sales["continuation"] is None:
        break
