# %%
import pandas as pd

df = pd.read_csv('collection_table_202311240842.csv')
df
# Out:
# /var/folders/k3/2w4zylcs0l12r34ky2dtqg5h0000gn/T/ipykernel_48868/2074070807.py:3: DtypeWarning: Columns (12,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('collection_table_202311240842.csv')
#            idx                               collection_id  network  \
# 0       294255  0x0000f22ffe0866ffb8834600dad9259cf4956853      bnb
# 1       292804  0x00a7112c4b151a77683eb6a79ef5600bf33a213d      bnb
# 2       292879  0x00fd05b17d884d86b964ceed8652efc8333b59fe      bnb
# 3        18757  0x01331e8427f6849930a81ee83c40f365be45a93b      bnb
# 4       294303  0x01dfc15d14cac26e91814fbb3da9ffdfa15502bb      bnb
# ...        ...                                         ...      ...
# 295394  293454  0xfeee476cfaf56c2f359a63500415d5a2c7f2f2b9  polygon
# 295395  294356  0xff41d7dfd0aa226d5097cb0d0f2a1a1c739f7731  polygon
# 295396  295353  0xff72d37314a0f1d38fb5f86be7f4223a3f87de5d  polygon
# ...

# %%
descriptions = df[['collection_id', 'collection_name', 'slug', 'description']].loc[df["description"].notnull()]
descriptions
# Out:
#                                      collection_id  \
# 0       0x0000f22ffe0866ffb8834600dad9259cf4956853
# 4       0x01dfc15d14cac26e91814fbb3da9ffdfa15502bb
# 10      0x07c87ae43494ce4e25f2d2ee91a280961d3ab99a
# 12      0x080537f59cb16f33cc96c135b58f4f5205f23e13
# 18      0x0a83cf5aeedfcef788dbae4ca7ef61e78c8f2c85
# ...                                            ...
# 295386  0xfe063cf67b1f05f7eafe351e9a67a290f74dda9b
# 295389  0xfe6dcb52b4d1b30c896765550dc9abe520a4393b
# 295392  0xfec90bc707fc93aefeb0c18c2eb56bc79d32163e
# 295395  0xff41d7dfd0aa226d5097cb0d0f2a1a1c739f7731
# 295398  0xffc7f5448540510625bb7ad48bd45ca899d2cb5f
#
#                                           collection_name  \
# 0                BSC Name Service .bnb - By Trust Domains
# 4                                             Owl Naughts
# 10                             Ultiverse - Moonlight Gift
# 12                           Computer generated space art
# ...

# %%
descriptions.to_excel('descriptions_202311240842.xlsx', index=False)
