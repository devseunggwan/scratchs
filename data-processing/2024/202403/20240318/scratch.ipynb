# %%
import polars as pl

df = pl.read_csv("data/raw/data.csv", encoding="euc-kr", ignore_errors=True)
df.write_csv("./data/processed/data.tsv", separator="\t")

# %%
import pandas as pd
from io import StringIO

data = """
    enter the snowflake table schemas(translated by copliot)
"""

df = pd.read_csv(StringIO(data), skipinitialspace=True)

# %%
df.to_csv("./processed.csv")
