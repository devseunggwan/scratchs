# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    "/Users/user/projects/scratchs/data-processing/2024/202405/20240507/2024-05-07T04-52_export.csv"
)
df
# Out:
#     Unnamed: 0  check_date  앱_누적방문자  앱_신규방문자  DAU   WAU    MAU  \
# 0            0  2024-05-06    35824        1  118   937  35290
# 1            1  2024-05-05    35823        6  113  1000  35290
# 2            2  2024-05-04    35817        8  123  2485  35290
# 3            3  2024-05-03    35809       10  174  3925  35290
# 4            4  2024-05-02    35799        9  163  5463  35300
# ..         ...         ...      ...      ...  ...   ...    ...
# 92          92  2024-02-04      153        8   32   252    607
# 93          93  2024-02-03      145        2   34   244    599
# 94          94  2024-02-02      143       20   69   243    597
# 95          95  2024-02-01      123       44   78   231    580
# 96          96  2024-01-31       79       79  114   218    538
#
#     playstore_daily_installs  appstore_daily_installs  \
# 0                        NaN                      NaN
# 1                        NaN                      6.0
# ...

# %%
for index, row in df.iterrows():
    # if None in row.values:
    print(row.values[9])
    print(type(row.values[9]))
    print(row.values[9] == None)
    print(row.values[9] == np.nan)
    break
# Out:
# nan
# <class 'float'>
# False
# False

# %%
df[df.iloc[0].isnull().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.11.5/envs/study/lib/python3.11/site-packages/pandas/core/generic.py in ?(cls, axis)
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/k3/2w4zylcs0l12r34ky2dtqg5h0000gn/T/ipykernel_90602/1354845393.py in ?()
# ----> 1 df[df.iloc[0].isnull().any(axis=1)]
#
# ~/.pyenv/versions/3.11.5/envs/study/lib/python3.11/site-packages/pandas/core/series.py in ?(self, axis, bool_only, skipna, **kwargs)
#    6143         **kwargs,
#    6144     ) -> bool:
# ...

# %%
for index, row in df.iterrows():
    if not row.isnull().any():
        print(row.check_date)
        break
# Out:
# 2024-05-03
