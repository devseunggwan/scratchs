# %%
import httpx

# %%
data = httpx.get("https://api.korbit.co.kr/v2/currencyPairs").json()

data = [item for item in data["data"] if item["status"] == "launched"]
data
# Out:
# [{'symbol': 'fil_krw', 'status': 'launched'},
#  {'symbol': 'sol_krw', 'status': 'launched'},
#  {'symbol': 'ape_krw', 'status': 'launched'},
#  {'symbol': 'bfc_krw', 'status': 'launched'},
#  {'symbol': 'enj_krw', 'status': 'launched'},
#  {'symbol': 'alpha_krw', 'status': 'launched'},
#  {'symbol': 'nmr_krw', 'status': 'launched'},
#  {'symbol': 'ethfi_krw', 'status': 'launched'},
#  {'symbol': 'mkr_krw', 'status': 'launched'},
#  {'symbol': 'op_krw', 'status': 'launched'},
#  {'symbol': 'icp_krw', 'status': 'launched'},
#  {'symbol': 'dydx_krw', 'status': 'launched'},
#  {'symbol': 'avax_krw', 'status': 'launched'},
#  {'symbol': 'tdrop_krw', 'status': 'launched'},
#  {'symbol': 'ondo_krw', 'status': 'launched'},
#  {'symbol': 'g_krw', 'status': 'launched'},
#  {'symbol': 'egld_krw', 'status': 'launched'},
#  {'symbol': 'flr_krw', 'status': 'launched'},
#  {'symbol': 'wbtc_krw', 'status': 'launched'},
#  {'symbol': 'yfi_krw', 'status': 'launched'},
# ...

# %%
data = httpx.get("https://api.upbit.com/v1/market/all").json()

data = [item for item in data if item["market"][:3] == "KRW"]
data
# Out:
# [{'market': 'KRW-BTC', 'korean_name': '비트코인', 'english_name': 'Bitcoin'},
#  {'market': 'KRW-ETH', 'korean_name': '이더리움', 'english_name': 'Ethereum'},
#  {'market': 'KRW-NEO', 'korean_name': '네오', 'english_name': 'NEO'},
#  {'market': 'KRW-MTL', 'korean_name': '메탈', 'english_name': 'Metal'},
#  {'market': 'KRW-XRP', 'korean_name': '엑스알피(리플)', 'english_name': 'XRP'},
#  {'market': 'KRW-ETC',
#   'korean_name': '이더리움클래식',
#   'english_name': 'Ethereum Classic'},
#  {'market': 'KRW-SNT',
#   'korean_name': '스테이터스네트워크토큰',
#   'english_name': 'Status Network Token'},
#  {'market': 'KRW-WAVES', 'korean_name': '웨이브', 'english_name': 'Waves'},
#  {'market': 'KRW-XEM', 'korean_name': '넴', 'english_name': 'NEM'},
#  {'market': 'KRW-QTUM', 'korean_name': '퀀텀', 'english_name': 'Qtum'},
#  {'market': 'KRW-LSK', 'korean_name': '리스크', 'english_name': 'Lisk'},
#  {'market': 'KRW-STEEM', 'korean_name': '스팀', 'english_name': 'Steem'},
# ...

# %%
httpx.get("https://api.bithumb.com/v1/market/all").json()

data = [item for item in data if item["market"][:3] == "KRW"]
data
# Out:
# [{'market': 'KRW-BTC', 'korean_name': '비트코인', 'english_name': 'Bitcoin'},
#  {'market': 'KRW-ETH', 'korean_name': '이더리움', 'english_name': 'Ethereum'},
#  {'market': 'KRW-NEO', 'korean_name': '네오', 'english_name': 'NEO'},
#  {'market': 'KRW-MTL', 'korean_name': '메탈', 'english_name': 'Metal'},
#  {'market': 'KRW-XRP', 'korean_name': '엑스알피(리플)', 'english_name': 'XRP'},
#  {'market': 'KRW-ETC',
#   'korean_name': '이더리움클래식',
#   'english_name': 'Ethereum Classic'},
#  {'market': 'KRW-SNT',
#   'korean_name': '스테이터스네트워크토큰',
#   'english_name': 'Status Network Token'},
#  {'market': 'KRW-WAVES', 'korean_name': '웨이브', 'english_name': 'Waves'},
#  {'market': 'KRW-XEM', 'korean_name': '넴', 'english_name': 'NEM'},
#  {'market': 'KRW-QTUM', 'korean_name': '퀀텀', 'english_name': 'Qtum'},
#  {'market': 'KRW-LSK', 'korean_name': '리스크', 'english_name': 'Lisk'},
#  {'market': 'KRW-STEEM', 'korean_name': '스팀', 'english_name': 'Steem'},
# ...

# %%
data = httpx.get("https://api.coinone.co.kr/public/v2/markets/KRW").json()

data = [item for item in data["markets"] if item["quote_currency"] == "KRW" and item["trade_status"] == 1]
data
# Out:
# [{'quote_currency': 'KRW',
#   'target_currency': 'TNSR',
#   'price_unit': '1.0',
#   'qty_unit': '0.00000001',
#   'max_order_amount': '1000000000.0',
#   'max_price': '10000000000.0',
#   'max_qty': '10000000000.0',
#   'min_order_amount': '5000.0',
#   'min_price': '0.0001',
#   'min_qty': '0.00000001',
#   'order_book_units': ['0.0', '10.0', '100.0'],
#   'maintenance_status': 0,
#   'trade_status': 1,
#   'order_types': ['limit', 'market', 'stop_limit']},
#  {'quote_currency': 'KRW',
#   'target_currency': 'STRK',
#   'price_unit': '0.1',
#   'qty_unit': '0.00000001',
#   'max_order_amount': '1000000000.0',
#   'max_price': '10000000000.0',
#   'max_qty': '10000000000.0',
#   'min_order_amount': '5000.0',
#   'min_price': '0.0001',
#   'min_qty': '0.00000001',
#   'order_book_units': ['0.0', '1.0', '10.0'],
#   'maintenance_status': 0,
#   'trade_status': 1,
#   'order_types': ['limit', 'market', 'stop_limit']},
#  {'quote_currency': 'KRW',
#   'target_currency': 'APP',
# ...
