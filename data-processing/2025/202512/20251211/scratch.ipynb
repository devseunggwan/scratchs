# %%
import duckdb

# %%
df = duckdb.read_json("./data/2025-12-10/order/*.json").df()

# %%
resp = []

for idx, item in df.iterrows():
    resp.extend(item["data"])

# %%
[item for item in resp if item["order_id"] == "2025120921515391"]

# %%
df = duckdb.read_json("./data/2025-12-11/order/*.json").df()

resp = []

for idx, item in df.iterrows():
    resp.extend(item["data"])


[item for item in resp if item["order_id"] == "2025120921515391"]
