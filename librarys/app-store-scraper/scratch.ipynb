# %%
# %pip install app-store-scraper

# %%
from app_store_scraper import AppStore
from pprint import pprint

minecraft = AppStore(country="nz", app_name="minecraft")
minecraft.review(how_many=20)

pprint(minecraft.reviews)
pprint(minecraft.reviews_count)
# Out:
# 2024-04-23 13:29:05,888 [INFO] Base - Searching for app id
# 2024-04-23 13:29:07,682 [INFO] Base - Initialised: AppStore('nz', 'minecraft', 479516143)
# 2024-04-23 13:29:07,683 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/nz/app/minecraft/id479516143
# 2024-04-23 13:29:07,976 [INFO] Base - [id:479516143] Fetched 20 reviews (20 fetched in total)
# [{'date': datetime.datetime(2021, 3, 19, 9, 37, 21),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'I love Minecraft but there is one problem for whom play Mine Zoo '
#             '2. It always crashes and exits your screen. You’ll have to '
#             'restart anything that you did at least 5 seconds ago. Mojang-you '
#             'are a legend but the crashes is my least favourite thing. The '
#             'crashes only happens on the IOS system (IPad). \n'
#             '\n'
#             'I was just playing some Mine Zoo 2, like always! I started '
#             'working on the Giraffe habitat for the largest enclosure in the '
#             'zoo. It crashed and I had to restart almost every progress that I '
#             'did since 5 seconds ago. I opened Mine Zoo 2 again and I '
#             'continued on the Habitat and it crashed again I got really '
#             'frustrated so I didn’t play Mine Zoo 2 that much anymore. Mojang, '
#             'if it was not you, ask Cyclone Designs, the creator of Mine Zoo '
#             '2.\n'
#             '\n'
#             'Thanks! Really appreciate it! 🤗',
#   'title': 'Stop the crashing, please.',
#   'userName': 'MobSlayer2011'},
#  {'date': datetime.datetime(2021, 3, 10, 9, 32, 18),
#   'isEdited': False,
#   'rating': 3,
#   'review': "Ayo so I love Minecraft, but three things I've noticed as of late "
#             'are that my skin (and other players) will always show up as Steve '
#             'in game, my skin can be seen in the skin editor but will always '
#             'be loading in the first screen, and for a couple of days now, I '
#             'haven\'t been able to get into my worlds. It gets to "Generating '
#             'World", get\'s almost through, then the loading bar disappears '
#             'and it just cycles through the game tips until I exit the app. '
#             'Oh, and my friend managed to join me and successfully get into my '
#             'world over Wi-Fi when it was still cycling the loading tips. Hope '
#             "ya'll see this and can fix these bugs, also I checked "
#             'compatibility and my iPad Air 2 is compatible. And I have the '
#             'most recent update as of December 16th\n'
#             '\n'
#             "It's now 10th March 2021 and the world thing is still happening. "
#             "It's kinda getting really annoying now, it works perfectly fine "
#             'on my friends iPad (exact same as mine), but never my iPad. I '
#             "really don't want to delete and redownload, as I would be losing "
#             "years of progress and memories. I really, really hope ya'll can "
#             'fix this.',
#   'title': 'Worlds not working?',
#   'userName': 'CarlyJW'},
#  {'date': datetime.datetime(2022, 10, 14, 0, 2, 25),
#   'isEdited': False,
#   'rating': 2,
#   'review': 'I have loved to play Minecraft for many many years, it has been '
#             'the funnest game iv ever experienced. But there’s just one '
#             'problem… \n'
#             'When ever I try to upload my world into realms it keeps saying an '
#             'error occurred, it also might say I have a bad connection. Even '
#             'though I have great internet I don’t know why it won’t upload. I '
#             'have read my articles and reddit post on how to resolve this '
#             'problem but none of them will work. The world I am trying to '
#             'upload is 128Mb and in survival (no cheats) it is my favourite '
#             'world of all time it since I started it with my friends before '
#             'the caves and cliffs updates. It has been a realm before but for '
#             'some reason it won’t work now. I would be most great full if u '
#             'could resolve this issue as I want to continue playing Minecraft '
#             'on this world on multiple platforms. And yes I have purchased '
#             'realms just the other day and it still won’t upload. So Mojang '
#             'please fix this problem.\n'
#             '\n'
#             'Yours sincerely: #1 Minecraft fan!',
#   'title': 'I love Minecraft but why dose this happen?',
#   'userName': 'kurtus2020'},
#  {'date': datetime.datetime(2021, 5, 25, 22, 59, 35),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I think this game is epic people out there who don’t find this '
#             'fun try and go on with some one else as well on the same world i '
#             'recon you would find it a whole lot more fun🤩🤩and please fix this '
#             'I have a ps4 and for some reason I am logged in but for some '
#             'reason the seed don’t let me use them and they don’t show up so '
#             'if you could fix that that would be '
#             'great🤩🤩🤩🤩🤩🤩🤩🤩😁😁😁😁😁😄😄😄😃😀😃😄😄😁😆😆😆😆😁😁😄😄😄😃😀😀one last thing (PLEASE FIX '
#             'THIS) for some reason it won’t let me join other people when they '
#             'are right next to me and we are on the same internet so yeah '
#             'that’s really anoying😣😡😡😡oh and if you could please make the '
#             'trees grow a whole lot more faster bc they grow REALLY SLOWLY so '
#             'please fix that as well thx so much for the latest updates I love '
#             'the pandas on survival this game is a MUST BUY',
#   'title': 'AWESOME🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩',
#   'userName': 'progamerfuitgummy'},
#  {'date': datetime.datetime(2020, 4, 3, 7, 41, 55),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve been playing the game since roses and dandelions were the '
#             'only flowers, there was only one type of fish, dark oak and '
#             'acacia didn’t exist and there were only red beds. I absolutely '
#             'loved (and still do love) this game.\n'
#             '\n'
#             'I think there are a few things that not only myself would like to '
#             'see be added to the game; banners can go onto beds creating even '
#             'better and unique colours/patterns, a new boss; whether it’s '
#             'another dragon found up in the sky or a new mob such as a giant '
#             'spider, I think everyone would agree that the ender dragon, the '
#             'wither and elder guardian just isn’t enough. I also think a new '
#             'wood/tree would be a nice feature. Perhaps a willow tree to '
#             'replace the oak ones found in swamps where the planks are tinted '
#             'a blue/green, this would give a lot more building opportunities. '
#             'And finally: dog textures. Cats come in a variety of colours such '
#             'as ginger, grey, white, black, ect. Dogs however, only have one '
#             'existing skin, the wolf texture with a changeable collar. I '
#             'believe there should be different textures found in different '
#             'biomes like for example; huskies found in snowy biomes, German '
#             'Shepard’s found in forests, Dalmatians found in extreme hills and '
#             'golden retrievers found in deserts. \n'
#             '\n'
#             'Hopefully the Mojang team sees this review and puts some of these '
#             'ideas into consideration. \n'
#             'Thanks,\n'
#             '-Bri :)',
#   'title': 'Update ideas',
#   'userName': 'Brianna-xxxo'},
#  {'date': datetime.datetime(2021, 4, 9, 5, 28, 32),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I love Minecraft but the only reason why I gave it one star is '
#             'because they should stop locking me out of my Account every time '
#             'I load in the game I made three accounts so far and I gotten to. '
#             'The point were I will delete the app on my iPad re-time I try to '
#             'recover my account it keeps on saying up wrong password when I '
#             'know that it’s the right password because I wrote it down. I just '
#             'wish they would stop locking me out every time and every time me '
#             'and my cousin load into a game we always hear weird sounds in '
#             'the. Background and we no it’s not the Version of the Minecraft '
#             'and I have recently been looking at the Internet to see what '
#             'people have been saying about that but nothings come up and I '
#             'just wish that all the. Stuff would stop. I thought this game was '
#             'Supposed to be a kids game and the stuff me and my cousin hear in '
#             'the background is very scary and would give kids nightmares at '
#             'night no it’s not me because my parents also here it and they are '
#             'also wanting to complain.',
#   'title': 'Love it but I wish all this stuff would just stop!!!',
#   'userName': 'Gacha life girl 221'},
#  {'date': datetime.datetime(2017, 12, 31, 20, 25, 10),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'I really like minecraft but I liked it better when it was simple. '
#             'All these new updates are annoying because it’s hard to find '
#             'stuff, make stuff, change settings, and all of that, while it was '
#             'simple before. Oh, and, talking about settings, that leads me '
#             'onto my biggest complaint. Ok, so me and my cousin where trying '
#             'to join one of her worlds, and what happened was one of us was on '
#             'creative, while the other was on survival! The settings don’t '
#             'work, this “ Xbox sign in” is utterly useless to some people, e.g '
#             'they don’t have an Xbox (me), and it just makes what used to be '
#             'my favourite game completely complicated and frustrating. I can’t '
#             'even keep up with all the updates! It’s just update after update '
#             'after update. I’m fed up with this! There’s SO many comments '
#             'saying (roughly) the same thing as me, so I’ll tell you what to '
#             'to, stop all the updates, or have one more to make minecraft more '
#             'simple, and LISTEN TO WHAT EVERYONE IS COMPLAINING ABOUT AND FIX '
#             'IT! \n'
#             '\n'
#             'From,\n'
#             'A very annoyed and fed up player.\n'
#             'P.S I have anger issues sorry',
#   'title': 'Annoying updates',
#   'userName': 'Ponies4me'},
#  {'date': datetime.datetime(2023, 10, 30, 19, 43, 7),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'Read the title Literally, I will go on for YEARS! Well, I don’t '
#             'have years, so I will go with my top 35. 1. Minecraft is fun. 2. '
#             'Minecraft is appropriate. 3. I like how you don’t pick where you '
#             'spawn. 4. So many different blocks! 5. You can build anything! 6. '
#             'No ads! 7. I like the option of creative mode. 8. Entertaining. '
#             '9. Popular. 10. So many possibilities! 11. So many places! 12. So '
#             'many secrets! 13. Just amazing! 14. Did you know on this you can '
#             'have rainbow sheep? 15. Also educational 16. Cool avatar options '
#             '17. I like how you can get so many things! 18. Lots of useful '
#             'items! 19. Lots of ways to trick other players 🤭 20. Addictive in '
#             'a good way 21. Fun things to do on app (e.g. ride rollercoasters, '
#             'build, fight mobs) 22. Can play',
#   'title': 'I LOVE YOU MINECRAFT THERE IS NOTHING WRONG WITH YOU',
#   'userName': 'duoviewer'},
#  {'date': datetime.datetime(2023, 6, 1, 3, 11, 11),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'Minecraft has been an outstanding game in the past history that I '
#             'have been playing it. I wish that the game just allowed devices '
#             'that aren’t the same brand to join each-other like if I could '
#             'join Minecraft from my phone onto a Xbox or something like that. '
#             'I would love to see what Minecraft has next to create! I also '
#             'recommend that Minecraft makes it able for friends from other '
#             'wifis to join such as whenever you go to another friends house or '
#             'a family members (whatever you want) you can add their wifi as a '
#             'joinable friend so that we can play with them without them '
#             'needing to come to our house and that we can play from different '
#             'places !',
#   'title': 'minecraft is amazing',
#   'userName': 'khffhfj'},
#  {'date': datetime.datetime(2021, 7, 14, 3, 18, 28),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I love Minecraft it’s the best ever but could use some new update '
#             'ideas ima share them now Im thinking of a specific item that can '
#             'repair anything in a anvil also maybe a new update for caves and '
#             'cliffs is for a new mob called the monkey it spawns in jungle '
#             'biomes and steals what your holding and runs away with it it can '
#             'also climb tree and to get your item back you have to kill it '
#             ';)   Another idea is to add new cliffs for the caves and “cliffs” '
#             'update I think that you could add some sort of biome that only '
#             'spawns in cliffs called the  magmas lair that is made out of '
#             'magma crying obsidian lava and is like a crater with hidden '
#             'chests with fireballs flint and steel blaze powder and lava '
#             'buckets it has magma cubes and a new mob called the lava worm '
#             'with swims in lava that’s all goodbye \n'
#             '\n'
#             'Robbie :)',
#   'title': 'Update ideas',
#   'userName': 'Jackoboss5456'},
#  {'date': datetime.datetime(2020, 9, 23, 7, 27, 56),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'This game is the game what is respect and no copy write reasons '
#             'what so ever. This game is 5+. When I played it I played '
#             'peaceful. I loved making my farm bigger and finding gold. I '
#             'didn’t like easy or hard, or other modes with mobs. I liked '
#             'creating modes this mode is like you can get unlimited blocks and '
#             'no mobs attack you. I build on flat lands. Like cool homes. It’s '
#             'fun. I like it. I think some people wouldn’t like it. Like I '
#             'don’t like roblox. Like it’s fun. I think you shouldn’t call any '
#             'one a noob. I mean even people in Minecraft who have 888 '
#             'diamonds, sometimes they have 64 dirt. Now the bad things. I '
#             'think endman are to scary. Even tho I’m over 6 I still I’m scared '
#             'of them. I don’t like the fact there’s not so much food. It’s '
#             'really not real. I lie Minecraft.',
#   'title': 'This game...',
#   'userName': 'fire girl 🙂'},
#  {'date': datetime.datetime(2022, 7, 30, 5, 6, 2),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I love Minecraft just as much as I love roblox! But the parents '
#             'who disagree need to get this into their “all knowing minds” \n'
#             '\n'
#             '1. Minecraft is a child friendly game made to entertain the host '
#             'of the world and everyone else on there\n'
#             '\n'
#             '2. Just because your child dies or something doesn’t mean that '
#             'it’s \n'
#             '“Too violent”\n'
#             '\n'
#             '3. Any contraption that the host/ player creates is rather a '
#             'lesson to do or not to do it in real life!\n'
#             '\n'
#             '4. Minecraft is appealing to all ages! So if you let your '
#             'child/friend show you around then you could have a complete '
#             'opposite opinion on this heavenly game\n'
#             '\n'
#             '5 the last lesson:\n'
#             '\n'
#             'Your child can do many things on Minecraft! And no they are NOT '
#             'performing satanic rituals but they are honouring the one and '
#             'only “Technoblade” or something else! A “ritual” in Minecraft is '
#             'actually us worshipping the lord that we are summoning! Or just '
#             'to remember! And just because your child says “blood for the '
#             'blood god” doesn’t mean “it’s MINDcraft” it’s Minecraft! And '
#             'it’ll stay that way! The blood god is the one and only '
#             'technoblade that I mentioned earlier! \n'
#             '\n'
#             'So please read this! I hope you got this',
#   'title': 'A message to the negative reviews about Minecraft',
#   'userName': 'gaming_cat'},
#  {'date': datetime.datetime(2020, 6, 28, 2, 53, 45),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I have been playing for as long as i can remember and i love the '
#             'game. I actually play on playstation but this is the easiest way '
#             'to write to you. I think it would be a good idea to be able to '
#             'train dogs and cats and you have to feed your pets. And it would '
#             'be great if all animals could sleep at night apart from nocturnal '
#             'animals. Also it would cool to feed an ore to a dog and they '
#             'would be able to sniff it out, or even be able to sniff out a '
#             'player by feeding them clothes or a tool that player has used. '
#             "Even if you can't manage all this i still love the game, thanks "
#             'Mojang and the amazing team to make mine craft a thing.',
#   'title': 'Awesome game, would be better with more creative ideas',
#   'userName': 'Liazgaming'},
#  {'date': datetime.datetime(2023, 9, 29, 5, 19, 39),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'So the reason why I’m writing this is only because there’s one '
#             'small detail that I’m sure other players have not noticed but '
#             'when making on creative mode when I want to destroy blocks it '
#             'takes a slightly bit longer and also I can’t hold down my screen '
#             'and delete blocks really fast like I used to and that is really '
#             'annoying when making a new creation so if you see this please '
#             'make the breaking blocks more smoother for creative mode because '
#             'it is annoying but anyways still my favourite childhood game I’d '
#             'I’ll still continue to use it just secretly rage over the '
#             'breaking speed. Definitely download Im just dramatic',
#   'title': 'From a person who played Minecraft all the time',
#   'userName': 'angry verifi'},
#  {'date': datetime.datetime(2017, 9, 28, 3, 37, 16),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'I love Minecraft so much! It is very funn and there always '
#             'something to do. But he recent update is really annoying. Every '
#             'time i go and play it is very laggy and drops out of the whole '
#             'game. Also i had some pet parrots and they disappeared after a '
#             'couple (minecraft) days. My biggest complaint is that i '
#             'downloaded some texture pack and one of them was a robot one, it '
#             'made it so when you make a iron golom it would turn into a huge '
#             'big robot that you could ride and shoot missiles. But instead the '
#             '"robot" still looked like a giant iron golom and you could ride '
#             'it but there was a massive glitch that made the game drop out. '
#             'Please fix this! I have already tried deleting and re-starting '
#             "the app but it didn't work.",
#   'title': 'Cool, but...',
#   'userName': 'gdhdbdjdb'},
#  {'date': datetime.datetime(2018, 9, 7, 4, 46, 26),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'I love this game but I do think you should add fireplaces and '
#             'when you cut a tree down it also gives firewood(branches) witch '
#             'you can put in the fireplace to heat up your house and different '
#             'firewood last longer and I think you need to all more animals '
#             'like deer, goats, different types of chickens (bc it gets boring '
#             'looking at the same white thing, different fruit trees, solar '
#             'panels and lights witch get powered buy the solar panels, '
#             'switches to turn on the lights, and big doors so you can make '
#             'barns, and also taxidermi animals for decoration of your house, '
#             'and ducks would be soooo cool, and bees for a bee hive witch you '
#             'can get honey from witch you can put on the bread.\n'
#             '\n'
#             'Please add this stuff and then many you might even get more '
#             'players\n'
#             '\n'
#             'Thank you',
#   'title': 'Stuff to add',
#   'userName': 'attack20010'},
#  {'date': datetime.datetime(2023, 9, 26, 20, 35, 2),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'Honestly, sometimes I hesitate thinking that Minecraft is worth '
#             'the money. But if you have a few spare dollars I would recommend '
#             'getting this. It’s good but there are a few flaws. I’m not gonna '
#             'name them, but this game is honesty a extremely well made game. '
#             'Yes, you should play it if you have the money to buy it! It’s an '
#             'amazing game and would recommend for ages 5+ you may have '
#             'different opinions on it, but this is just mine. Overall the game '
#             'is a good 9.9/10. There’s just those small flaws ruining it '
#             '(sometimes) \n'
#             '\n'
#             'This is just my thought and opinion on it, you may have different '
#             'opinions that’s ok!',
#   'title': 'Minecraft',
#   'userName': 'mech ;D'},
#  {'date': datetime.datetime(2020, 11, 24, 4, 27, 48),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'Hi can you please help me \n'
#             'I was playing on my world just haching some turtles when I saw a '
#             'zombie in the distance. I saw that it was holding a rotten flesh '
#             'so I went over to investigate I saw that the zombie who was '
#             'standing on a hill was frozen. I looked down to the hill and saw '
#             'a line of zombie villagers and they where frozen. All the mobs in '
#             'that area where frozen including my pets. It looked like a zombie '
#             'giving orders to his army of zombie villagers. I freaked out a '
#             'bit but when I came back on to my world everything was fine and '
#             'the zombies had disappeared.\n'
#             'Please can you help by investigating this\n'
#             'Love your game \n'
#             'A minecraft player :)',
#   'title': 'Hey can you help',
#   'userName': 'Leopard girl 404'},
#  {'date': datetime.datetime(2018, 6, 10, 8, 33, 53),
#   'isEdited': False,
#   'rating': 5,
#   'review': 'I’ve had minecraft for about three years now and it just keeps on '
#             'getting better and better! Yes, there have been a couple of '
#             'updates at the end of 2017 that made a lot of peoples’ games '
#             'crash frequently, (including mine) but mojang fixed it all up. I '
#             'also LOVE the new aquatic update. (Thx Mojang!) I also think this '
#             'game is perfect for all ages 6 and up, I got it when I was 7, and '
#             'it’s super easy to understand. Minecraft lets your imagination '
#             'run wild with imagination, and you can create literally anything! '
#             'Highly recommended, although don’t play too often, I can '
#             'guarantee you’ll get addicted! Keep up the awesome job Mojang! 👍🏻',
#   'title': 'AMAZINGGGGG!!',
#   'userName': 'Frith Williams'},
#  {'date': datetime.datetime(2020, 9, 9, 19, 4, 32),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'Minecraft is a great game but yesterday I decided to buy a 10 '
#             'player realm for my friends to play on. I brought it last night '
#             'and it said there was an error creating the realm and told me to '
#             'check back later cause it said it would create it. So I waited '
#             'and checked on it every 20 minutes but It hadn’t created and then '
#             'when i went on to create a new realm it said that the purchase '
#             'succeeded but the realm wasn’t created. I tried multiple times '
#             'and the realm wont create. Even tried it this morning and it '
#             'won’t work. Plz fix this cause my money has been spent on the '
#             'realm and my friends and I can’t wait to play.',
#   'title': 'Realms',
#   'userName': 'Hello_737'}]
# 20

# %%
enta = AppStore(country="kr", app_name="enta")
# Out:
# 2024-04-23 13:31:14,803 [INFO] Base - Searching for app id
# 2024-04-23 13:31:16,283 [INFO] Base - Initialised: AppStore('kr', 'enta', 6467370196)
# 2024-04-23 13:31:16,283 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/kr/app/enta/id6467370196

# %%
pprint(enta.reviews)
# Out:
# []
